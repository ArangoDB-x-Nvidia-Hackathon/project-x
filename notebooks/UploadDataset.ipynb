# %%
import os
from dotenv import load_dotenv
from arango import ArangoClient

# %%
# Load environment variables
load_dotenv()
# Out:
# True

# %%
# Initialize the ArangoDB client.
host = os.getenv("HOST")
username = os.getenv("USER")
password = os.getenv("PASSWORD")

# %%
# Connect to ArangoDB
client = ArangoClient(hosts=host)
sys_db = client.db('_system', username=username, password=password)

# Create 'events' database if it doesn't exist
if not sys_db.has_database('events global'):
    sys_db.create_database('events global')

# %%
# Connect to the events database
db = client.db('events global', username=username, password=password)

# Create collections if they don't exist
if not db.has_collection('events'):
    events = db.create_collection('events')
if not db.has_collection('countries'):
    countries = db.create_collection('countries')
if not db.has_collection('groups'):
    groups = db.create_collection('groups')

# %%
# Create edge collections as regular edge collections
if not db.has_collection('located_in'):
    located_in = db.create_collection('located_in', edge=True)
if not db.has_collection('caused_by'):
    caused_by = db.create_collection('caused_by', edge=True)

# %%
# Create graph to define the relationships
if not db.has_graph('events_graph'):
    graph = db.create_graph('events_graph')
    
    # Add edge definitions to the graph
    graph.create_edge_definition(
        edge_collection='located_in',
        from_vertex_collections=['events'],
        to_vertex_collections=['countries']
    )
    
    graph.create_edge_definition(
        edge_collection='caused_by',
        from_vertex_collections=['groups'],
        to_vertex_collections=['events']
    )
else:
    graph = db.graph('events_graph')

# %%
# Access collections
events = db.collection('events')
countries = db.collection('countries')
groups = db.collection('groups')
located_in = db.collection('located_in')
caused_by = db.collection('caused_by')

# %%
# Function to process and upload your dataset
def upload_dataset(dataset):
    # Track countries and groups we've already added
    added_countries = set()
    added_groups = set()
    
    for record in dataset:
        # Create event document
        event_key = f"{record['Cleaned Incident']}_{record['Year']}".replace(' ', '_')
        event_doc = {
            '_key': event_key,
            'incident_name': record['Cleaned Incident'],
            'year': record['Year'],
            'event_type': record['Cleaned Event'],
            'impact': record['Cleaned Impact'],
            'responsible_group': record['Cleaned Group'],
            'outcome': record['Cleaned Outcome'],
            'country': record['Location'],
            'latitude': record['Latitude'],
            'longitude': record['Longitude']
        }
        
        # Add event document
        try:
            events.insert(event_doc)
            print(f"Added event: {event_key}")
        except Exception as e:
            print(f"Error adding event {event_key}: {e}")
        
        # Add country if not already added
        country_key = record['Location'].replace(' ', '_')
        if country_key not in added_countries:
            country_doc = {
                '_key': country_key,
                'name': record['Location'],
                'latitude': record['Latitude'],
                'longitude': record['Longitude']
            }
            
            try:
                countries.insert(country_doc)
                added_countries.add(country_key)
                print(f"Added country: {country_key}")
            except Exception as e:
                print(f"Error adding country {country_key}: {e}")
        
        # Connect event to country
        edge_doc = {
            '_from': f"events/{event_key}",
            '_to': f"countries/{country_key}"
        }
        
        try:
            located_in.insert(edge_doc)
            print(f"Added location edge: {event_key} -> {country_key}")
        except Exception as e:
            print(f"Error adding location edge: {e}")
        
        # Add responsible group if available and not already added
        if record['Cleaned Group'] and record['Cleaned Group'] != 'Unknown':
            group_key = record['Cleaned Group'].replace(' ', '_')
            
            if group_key not in added_groups:
                group_doc = {
                    '_key': group_key,
                    'name': record['Cleaned Group']
                }
                
                try:
                    groups.insert(group_doc)
                    added_groups.add(group_key)
                    print(f"Added group: {group_key}")
                except Exception as e:
                    print(f"Error adding group {group_key}: {e}")
            
            # Connect group to event
            edge_doc = {
                '_from': f"groups/{group_key}",
                '_to': f"events/{event_key}"
            }
            
            try:
                caused_by.insert(edge_doc)
                print(f"Added causation edge: {group_key} -> {event_key}")
            except Exception as e:
                print(f"Error adding causation edge: {e}")

# %%
import pandas as pd

# Load from CSV
df = pd.read_csv('processed_dataset.csv')
cleaned_data = df.to_dict('records')

# Then upload it
upload_dataset(cleaned_data)
# Out:
# Added event: establishment_of_the_delhi_sultanate_1206
# Added country: India
# Added location edge: establishment_of_the_delhi_sultanate_1206 -> India
# Added group: qutbunknownudunknowndin_aibak
# Added causation edge: qutbunknownudunknowndin_aibak -> establishment_of_the_delhi_sultanate_1206
# Added event: battle_of_panipat_1526
# Added location edge: battle_of_panipat_1526 -> India
# Added group: babur
# Added causation edge: babur -> battle_of_panipat_1526
# Added event: establishment_of_british_raj_1858
# Added location edge: establishment_of_british_raj_1858 -> India
# Added group: british_east_india_companyempire
# Added causation edge: british_east_india_companyempire -> establishment_of_british_raj_1858
# Added event: partition_of_india_1947
# Added location edge: partition_of_india_1947 -> India
# Added group: british_empire,_indian_political_leaders
# Added causation edge: british_empire,_indian_political_leaders -> partition_of_india_1947
# Added event: indounknownpakistani_war_of_1971_1971
# Added location edge: indounknownpakistani_war_of_1971_1971 -> India
# Added group: indian_military,_mukti_bahini
# Added causation edge: indian_military,_mukti_bahini -> indounknownpakistani_war_of_1971_1971
# Added event: pokhranunknownii_nuclear_tests_1998
# Added location edge: pokhranunknownii_nuclear_tests_1998 -> India
# Added group: atal_bihari_vajpayee
# Added causation edge: atal_bihari_vajpayee -> pokhranunknownii_nuclear_tests_1998
# Added event: mumbai_terror_attacks_2008
# Added location edge: mumbai_terror_attacks_2008 -> India
# Added group: lashkarunknowneunknowntaiba
# Added causation edge: lashkarunknowneunknowntaiba -> mumbai_terror_attacks_2008
# Added event: arrival_of_vasco_da_gama_1498
# Added location edge: arrival_of_vasco_da_gama_1498 -> India
# Added group: vasco_da_gama
# Added causation edge: vasco_da_gama -> arrival_of_vasco_da_gama_1498
# Added event: battle_of_plassey_1757
# Added location edge: battle_of_plassey_1757 -> India
# Added group: east_india_company
# Added causation edge: east_india_company -> battle_of_plassey_1757
# Added event: first_war_of_indian_independence_1857
# Added location edge: first_war_of_indian_independence_1857 -> India
# Added group: indian_soldiers,_british_east_india_company
# Added causation edge: indian_soldiers,_british_east_india_company -> first_war_of_indian_independence_1857
# Added event: swadeshi_movement_1905
# Added location edge: swadeshi_movement_1905 -> India
# Added group: indian_national_congress
# Added causation edge: indian_national_congress -> swadeshi_movement_1905
# Added event: green_revolution_1960
# Added location edge: green_revolution_1960 -> India
# Added group: m.s._swaminathan,_norman_borlaug
# Added causation edge: m.s._swaminathan,_norman_borlaug -> green_revolution_1960
# Added event: operation_blue_star_1984
# Added location edge: operation_blue_star_1984 -> India
# Added group: indian_government,_sikh_militants
# Added causation edge: indian_government,_sikh_militants -> operation_blue_star_1984
# Added event: kargil_war_1999
# Added location edge: kargil_war_1999 -> India
# Added group: indian_government,_pakistani_military
# Added causation edge: indian_government,_pakistani_military -> kargil_war_1999
# Added event: right_to_information_act_enacted_2005
# Added location edge: right_to_information_act_enacted_2005 -> India
# Added group: government_of_india
# Added causation edge: government_of_india -> right_to_information_act_enacted_2005
# Added event: nirbhaya_case_2012
# Added location edge: nirbhaya_case_2012 -> India
# Added group: indian_society,_government_of_india
# Added causation edge: indian_society,_government_of_india -> nirbhaya_case_2012
# Added event: launch_of_5g_services_2022
# Added location edge: launch_of_5g_services_2022 -> India
# Added group: telecom_companies,_government_of_india
# Added causation edge: telecom_companies,_government_of_india -> launch_of_5g_services_2022
# Added event: ram_mandir_bhoomi_pujan_2020
# Added location edge: ram_mandir_bhoomi_pujan_2020 -> India
# Added group: government_of_india,_hindu_activists
# Added causation edge: government_of_india,_hindu_activists -> ram_mandir_bhoomi_pujan_2020
# Added event: indias_first_hyperloop_project_announcement_2018
# Added location edge: indias_first_hyperloop_project_announcement_2018 -> India
# Added group: virgin_hyperloop_one,_state_government
# Added causation edge: virgin_hyperloop_one,_state_government -> indias_first_hyperloop_project_announcement_2018
# Added event: indian_independence_1947
# Added location edge: indian_independence_1947 -> India
# Added group: indian_national_congress,_muslim_league
# Added causation edge: indian_national_congress,_muslim_league -> indian_independence_1947
# Added event: first_general_elections_1951
# Added location edge: first_general_elections_1951 -> India
# Added causation edge: government_of_india -> first_general_elections_1951
# Added event: sinounknownindian_war_1962
# Added location edge: sinounknownindian_war_1962 -> India
# Added group: india,_china
# Added causation edge: india,_china -> sinounknownindian_war_1962
# Added event: first_nuclear_test_smiling_buddha_1974
# Added location edge: first_nuclear_test_smiling_buddha_1974 -> India
# Added causation edge: government_of_india -> first_nuclear_test_smiling_buddha_1974
# Added event: emergency_declared_by_indira_gandhi_1975
# Added location edge: emergency_declared_by_indira_gandhi_1975 -> India
# Added group: indira_gandhi,_government_of_india
# Added causation edge: indira_gandhi,_government_of_india -> emergency_declared_by_indira_gandhi_1975
# Added event: bhopal_gas_tragedy_1984
# Added location edge: bhopal_gas_tragedy_1984 -> India
# Added group: union_carbide_corporation
# Added causation edge: union_carbide_corporation -> bhopal_gas_tragedy_1984
# Added event: economic_reforms_and_liberalization_1991
# Added location edge: economic_reforms_and_liberalization_1991 -> India
# Added group: manmohan_singh,_p.v._narasimha_rao
# Added causation edge: manmohan_singh,_p.v._narasimha_rao -> economic_reforms_and_liberalization_1991
# Added event: kandahar_hijacking_ic_814_1999
# Added location edge: kandahar_hijacking_ic_814_1999 -> India
# Added group: hijackers,_indian_government
# Added causation edge: hijackers,_indian_government -> kandahar_hijacking_ic_814_1999
# Added event: 2001_indian_parliament_attack_2001
# Added location edge: 2001_indian_parliament_attack_2001 -> India
# Added group: terrorist_groups,_government_of_india
# Added causation edge: terrorist_groups,_government_of_india -> 2001_indian_parliament_attack_2001
# Added event: right_to_education_act_2009
# Added location edge: right_to_education_act_2009 -> India
# Added causation edge: government_of_india -> right_to_education_act_2009
# Added event: article_370_revocation_for_jammu__kashmir_2019
# Added location edge: article_370_revocation_for_jammu__kashmir_2019 -> India
# Added causation edge: government_of_india -> article_370_revocation_for_jammu__kashmir_2019
# Added event: supreme_court_verdict_on_ayodhya_2019
# Added location edge: supreme_court_verdict_on_ayodhya_2019 -> India
# Added group: supreme_court_of_india
# Added causation edge: supreme_court_of_india -> supreme_court_verdict_on_ayodhya_2019
# Added event: opening_of_bandraunknownworli_sea_link_2009
# Added location edge: opening_of_bandraunknownworli_sea_link_2009 -> India
# Added group: government_of_maharashtra
# Added causation edge: government_of_maharashtra -> opening_of_bandraunknownworli_sea_link_2009
# Added event: statue_of_unity_unveiled_2018
# Added location edge: statue_of_unity_unveiled_2018 -> India
# Added causation edge: government_of_india -> statue_of_unity_unveiled_2018
# Added event: triple_talaq_bill_passed_2019
# Added location edge: triple_talaq_bill_passed_2019 -> India
# Added group: parliament_of_india
# Added causation edge: parliament_of_india -> triple_talaq_bill_passed_2019
# Added event: indias_first_transgender_university_2020
# Added location edge: indias_first_transgender_university_2020 -> India
# Added group: dr._akhilesh_das_gupta_foundation
# Added causation edge: dr._akhilesh_das_gupta_foundation -> indias_first_transgender_university_2020
# Added event: nationwide_lockdown_due_to_covidunknown19_2020
# Added location edge: nationwide_lockdown_due_to_covidunknown19_2020 -> India
# Added causation edge: government_of_india -> nationwide_lockdown_due_to_covidunknown19_2020
# Added event: historic_win_in_cricket_world_cup_1983_1983
# Added location edge: historic_win_in_cricket_world_cup_1983_1983 -> India
# Added group: indian_cricket_team
# Added causation edge: indian_cricket_team -> historic_win_in_cricket_world_cup_1983_1983
# Added event: 2013_uttarakhand_floods_2013
# Added location edge: 2013_uttarakhand_floods_2013 -> India
# Added group: state_government,_national_disaster_response_force
# Added causation edge: state_government,_national_disaster_response_force -> 2013_uttarakhand_floods_2013
# Added event: indian_mars_orbiter_mission_success_2014
# Added location edge: indian_mars_orbiter_mission_success_2014 -> India
# Added group: isro
# Added causation edge: isro -> indian_mars_orbiter_mission_success_2014
# Added event: india_wins_icc_t20_world_cup_2007_2007
# Added location edge: india_wins_icc_t20_world_cup_2007_2007 -> India
# Added causation edge: indian_cricket_team -> india_wins_icc_t20_world_cup_2007_2007
# Added event: indias_demonetisation_campaign_2016
# Added location edge: indias_demonetisation_campaign_2016 -> India
# Added group: government_of_india,_prime_minister_narendra_modi
# Added causation edge: government_of_india,_prime_minister_narendra_modi -> indias_demonetisation_campaign_2016
# Added event: introduction_of_upi_unified_payment_interface_2016
# Added location edge: introduction_of_upi_unified_payment_interface_2016 -> India
# Added group: national_payments_corporation_of_india_npci
# Added causation edge: national_payments_corporation_of_india_npci -> introduction_of_upi_unified_payment_interface_2016
# Added event: jio_telecom_launch_2016
# Added location edge: jio_telecom_launch_2016 -> India
# Added group: reliance_industries
# Added causation edge: reliance_industries -> jio_telecom_launch_2016
# Added event: abolition_of_instant_triple_talaq_2019
# Added location edge: abolition_of_instant_triple_talaq_2019 -> India
# Added causation edge: parliament_of_india -> abolition_of_instant_triple_talaq_2019
# Added event: asiatic_lion_census_showing_population_increase_2020
# Added location edge: asiatic_lion_census_showing_population_increase_2020 -> India
# Added group: wildlife_conservationists,_government_of_gujarat
# Added causation edge: wildlife_conservationists,_government_of_gujarat -> asiatic_lion_census_showing_population_increase_2020
# Added event: decriminalisation_of_section_377_2018
# Added location edge: decriminalisation_of_section_377_2018 -> India
# Added causation edge: supreme_court_of_india -> decriminalisation_of_section_377_2018
# Added event: launch_of_chandrayaanunknown1_2008
# Added location edge: launch_of_chandrayaanunknown1_2008 -> India
# Added group: indian_space_research_organisation_isro
# Added causation edge: indian_space_research_organisation_isro -> launch_of_chandrayaanunknown1_2008
# Added event: start_of_swachh_bharat_mission_2014
# Added location edge: start_of_swachh_bharat_mission_2014 -> India
# Added causation edge: government_of_india,_prime_minister_narendra_modi -> start_of_swachh_bharat_mission_2014
# Added event: pulwama_terrorist_attack_2019
# Added location edge: pulwama_terrorist_attack_2019 -> India
# Added group: jaishunknowneunknownmohammed
# Added causation edge: jaishunknowneunknownmohammed -> pulwama_terrorist_attack_2019
# Added event: historic_solar_alliance_initiative_2015
# Added location edge: historic_solar_alliance_initiative_2015 -> India
# Added group: government_of_india,_france
# Added causation edge: government_of_india,_france -> historic_solar_alliance_initiative_2015
# Added event: gst_goods_and_services_tax_implementation_2017
# Added location edge: gst_goods_and_services_tax_implementation_2017 -> India
# Added causation edge: government_of_india -> gst_goods_and_services_tax_implementation_2017
# Added event: citizenship_amendment_act_caa_implementation_2019
# Added location edge: citizenship_amendment_act_caa_implementation_2019 -> India
# Added causation edge: government_of_india -> citizenship_amendment_act_caa_implementation_2019
# Added event: 2016_uri_attack_and_subsequent_surgical_strikes_2016
# Added location edge: 2016_uri_attack_and_subsequent_surgical_strikes_2016 -> India
# Added group: indian_army
# Added causation edge: indian_army -> 2016_uri_attack_and_subsequent_surgical_strikes_2016
# Added event: formation_of_indian_national_congress_1885
# Added location edge: formation_of_indian_national_congress_1885 -> India
# Added group: allan_octavian_hume,_indian_leaders
# Added causation edge: allan_octavian_hume,_indian_leaders -> formation_of_indian_national_congress_1885
# Added event: partition_of_bengal_1905
# Added location edge: partition_of_bengal_1905 -> India
# Added group: lord_curzon
# Added causation edge: lord_curzon -> partition_of_bengal_1905
# Added event: jallianwala_bagh_massacre_1919
# Added location edge: jallianwala_bagh_massacre_1919 -> India
# Added group: general_dyer
# Added causation edge: general_dyer -> jallianwala_bagh_massacre_1919
# Added event: nonunknowncooperation_movement_1920
# Added location edge: nonunknowncooperation_movement_1920 -> India
# Added group: mahatma_gandhi
# Added causation edge: mahatma_gandhi -> nonunknowncooperation_movement_1920
# Added event: chauri_chaura_incident_1922
# Added location edge: chauri_chaura_incident_1922 -> India
# Added group: indian_protesters
# Added causation edge: indian_protesters -> chauri_chaura_incident_1922
# Added event: dandi_march_1930
# Added location edge: dandi_march_1930 -> India
# Added causation edge: mahatma_gandhi -> dandi_march_1930
# Added event: first_round_table_conference_1930
# Added country: UK
# Added location edge: first_round_table_conference_1930 -> UK
# Added group: british_government
# Added causation edge: british_government -> first_round_table_conference_1930
# Added event: purna_swaraj_declaration_1930
# Added location edge: purna_swaraj_declaration_1930 -> India
# Added causation edge: indian_national_congress -> purna_swaraj_declaration_1930
# Added event: quit_india_movement_1942
# Added location edge: quit_india_movement_1942 -> India
# Added group: mahatma_gandhi,_indian_national_congress
# Added causation edge: mahatma_gandhi,_indian_national_congress -> quit_india_movement_1942
# Added event: cripps_mission_1942
# Added location edge: cripps_mission_1942 -> India
# Added group: sir_stafford_cripps
# Added causation edge: sir_stafford_cripps -> cripps_mission_1942
# Added event: bengal_famine_of_1943_1943
# Added location edge: bengal_famine_of_1943_1943 -> India
# Added group: british_administration
# Added causation edge: british_administration -> bengal_famine_of_1943_1943
# Added event: partition_plan_announced_1947
# Added location edge: partition_plan_announced_1947 -> India
# Added group: lord_mountbatten
# Added causation edge: lord_mountbatten -> partition_plan_announced_1947
# Added event: integration_of_princely_states_1947
# Added location edge: integration_of_princely_states_1947 -> India
# Added group: sardar_vallabhbhai_patel
# Added causation edge: sardar_vallabhbhai_patel -> integration_of_princely_states_1947
# Added event: constitution_of_india_adopted_1950
# Added location edge: constitution_of_india_adopted_1950 -> India
# Added group: constituent_assembly_of_india
# Added causation edge: constituent_assembly_of_india -> constitution_of_india_adopted_1950
# Added event: reserve_bank_of_india_rbi_1935
# Added location edge: reserve_bank_of_india_rbi_1935 -> India
# Added group: british_government_preunknownindependence
# Added causation edge: british_government_preunknownindependence -> reserve_bank_of_india_rbi_1935
# Added event: indian_space_research_organisation_isro_1969
# Added location edge: indian_space_research_organisation_isro_1969 -> India
# Added causation edge: government_of_india -> indian_space_research_organisation_isro_1969
# Added event: bharatiya_janata_party_bjp_1980
# Added location edge: bharatiya_janata_party_bjp_1980 -> India
# Added group: atal_bihari_vajpayee,_l.k._advani
# Added causation edge: atal_bihari_vajpayee,_l.k._advani -> bharatiya_janata_party_bjp_1980
# Added event: securities_and_exchange_board_of_india_sebi_1988
# Added location edge: securities_and_exchange_board_of_india_sebi_1988 -> India
# Added causation edge: government_of_india -> securities_and_exchange_board_of_india_sebi_1988
# Added event: taj_mahal_1653
# Added location edge: taj_mahal_1653 -> India
# Added group: emperor_shah_jahan
# Added causation edge: emperor_shah_jahan -> taj_mahal_1653
# Added event: golden_temple_harmandir_sahib_1585
# Added location edge: golden_temple_harmandir_sahib_1585 -> India
# Added group: guru_arjan
# Added causation edge: guru_arjan -> golden_temple_harmandir_sahib_1585
# Added event: creation_of_pakistan_1947
# Added country: Pakistan
# Added location edge: creation_of_pakistan_1947 -> Pakistan
# Added group: muhammad_ali_jinnah
# Added causation edge: muhammad_ali_jinnah -> creation_of_pakistan_1947
# Added event: first_indounknownpak_war_1947
# Added location edge: first_indounknownpak_war_1947 -> Pakistan
# Added group: india_and_pakistan
# Added causation edge: india_and_pakistan -> first_indounknownpak_war_1947
# Added event: pakistan_joins_the_united_nations_1947
# Added location edge: pakistan_joins_the_united_nations_1947 -> Pakistan
# Added group: government_of_pakistan
# Added causation edge: government_of_pakistan -> pakistan_joins_the_united_nations_1947
# Added event: first_constitution_of_pakistan_1956
# Added location edge: first_constitution_of_pakistan_1956 -> Pakistan
# Added group: constituent_assembly_of_pakistan
# Added causation edge: constituent_assembly_of_pakistan -> first_constitution_of_pakistan_1956
# Added event: east_pakistan_demands_autonomy_1971
# Added location edge: east_pakistan_demands_autonomy_1971 -> Pakistan
# Added group: sheikh_mujibur_rahman
# Added causation edge: sheikh_mujibur_rahman -> east_pakistan_demands_autonomy_1971
# Added event: independence_of_bangladesh_1971
# Added location edge: independence_of_bangladesh_1971 -> Pakistan
# Added group: indian_armed_forces,_mukti_bahini
# Added causation edge: indian_armed_forces,_mukti_bahini -> independence_of_bangladesh_1971
# Added event: pakistans_nuclear_tests_chagaiunknowni_1998
# Added location edge: pakistans_nuclear_tests_chagaiunknowni_1998 -> Pakistan
# Added causation edge: government_of_pakistan -> pakistans_nuclear_tests_chagaiunknowni_1998
# Added event: kargil_conflict_1999
# Added location edge: kargil_conflict_1999 -> Pakistan
# Added causation edge: india_and_pakistan -> kargil_conflict_1999
# Added event: 2005_kashmir_earthquake_2005
# Added location edge: 2005_kashmir_earthquake_2005 -> Pakistan
# Added group: government_of_pakistan,_international_aid
# Added causation edge: government_of_pakistan,_international_aid -> 2005_kashmir_earthquake_2005
# Added event: assassination_of_benazir_bhutto_2007
# Added location edge: assassination_of_benazir_bhutto_2007 -> Pakistan
# Added group: unknown_assailants
# Added causation edge: unknown_assailants -> assassination_of_benazir_bhutto_2007
# Added event: operation_zarbunknowneunknownazb_2014
# Added location edge: operation_zarbunknowneunknownazb_2014 -> Pakistan
# Added group: pakistan_armed_forces
# Added causation edge: pakistan_armed_forces -> operation_zarbunknowneunknownazb_2014
# Added event: 2014_peshawar_school_massacre_2014
# Added location edge: 2014_peshawar_school_massacre_2014 -> Pakistan
# Added group: tehrikunknowniunknowntaliban_pakistan
# Added causation edge: tehrikunknowniunknowntaliban_pakistan -> 2014_peshawar_school_massacre_2014
# Added event: chinaunknownpakistan_economic_corridor_cpec_agreement_2015
# Added location edge: chinaunknownpakistan_economic_corridor_cpec_agreement_2015 -> Pakistan
# Added group: government_of_pakistan,_china
# Added causation edge: government_of_pakistan,_china -> chinaunknownpakistan_economic_corridor_cpec_agreement_2015
# Added event: panama_papers_case__disqualification_of_pm_nawaz_sharif_2017
# Added location edge: panama_papers_case__disqualification_of_pm_nawaz_sharif_2017 -> Pakistan
# Added group: supreme_court_of_pakistan
# Added causation edge: supreme_court_of_pakistan -> panama_papers_case__disqualification_of_pm_nawaz_sharif_2017
# Added event: kartarpur_corridor_opening_2019
# Added location edge: kartarpur_corridor_opening_2019 -> Pakistan
# Added group: governments_of_pakistan_and_india
# Added causation edge: governments_of_pakistan_and_india -> kartarpur_corridor_opening_2019
# Added event: fatf_grey_list_2018
# Added location edge: fatf_grey_list_2018 -> Pakistan
# Added group: financial_action_task_force_fatf
# Added causation edge: financial_action_task_force_fatf -> fatf_grey_list_2018
# Added event: imran_khan_elected_as_prime_minister_2018
# Added location edge: imran_khan_elected_as_prime_minister_2018 -> Pakistan
# Added group: pakistan_tehreekunknowneunknowninsaf_pti
# Added causation edge: pakistan_tehreekunknowneunknowninsaf_pti -> imran_khan_elected_as_prime_minister_2018
# Added event: abolition_of_fata_2018
# Added location edge: abolition_of_fata_2018 -> Pakistan
# Added causation edge: government_of_pakistan -> abolition_of_fata_2018
# Added event: 2019_pulwama_attack_and_indiaunknownpakistan_standoff_2019
# Added location edge: 2019_pulwama_attack_and_indiaunknownpakistan_standoff_2019 -> Pakistan
# Added group: jaishunknowneunknownmohammed,_governments_of_india_and_pakistan
# Added causation edge: jaishunknowneunknownmohammed,_governments_of_india_and_pakistan -> 2019_pulwama_attack_and_indiaunknownpakistan_standoff_2019
# Added event: minarunknowneunknownpakistan_construction_1960
# Added location edge: minarunknowneunknownpakistan_construction_1960 -> Pakistan
# Added causation edge: government_of_pakistan -> minarunknowneunknownpakistan_construction_1960
# Added event: lahore_resolution_pakistan_resolution_1940
# Added location edge: lahore_resolution_pakistan_resolution_1940 -> Pakistan
# Added group: allunknownindia_muslim_league
# Added causation edge: allunknownindia_muslim_league -> lahore_resolution_pakistan_resolution_1940
# Added event: siachen_glacier_conflict_1984
# Added location edge: siachen_glacier_conflict_1984 -> Pakistan
# Added causation edge: india_and_pakistan -> siachen_glacier_conflict_1984
# Added event: indus_water_treaty_1960
# Added location edge: indus_water_treaty_1960 -> Pakistan
# Added group: india,_pakistan,_world_bank
# Added causation edge: india,_pakistan,_world_bank -> indus_water_treaty_1960
# Added event: pakistan_atomic_energy_commission_establishment_1956
# Added location edge: pakistan_atomic_energy_commission_establishment_1956 -> Pakistan
# Added causation edge: government_of_pakistan -> pakistan_atomic_energy_commission_establishment_1956
# Added event: nationalization_in_pakistan_1972
# Added location edge: nationalization_in_pakistan_1972 -> Pakistan
# Added group: zulfikar_ali_bhutto
# Added causation edge: zulfikar_ali_bhutto -> nationalization_in_pakistan_1972
# Added event: islamabad_declaration_1980
# Added location edge: islamabad_declaration_1980 -> Pakistan
# Added group: leaders_of_muslimunknownmajority_countries
# Added causation edge: leaders_of_muslimunknownmajority_countries -> islamabad_declaration_1980
# Added event: motorway_network_development_1997
# Added location edge: motorway_network_development_1997 -> Pakistan
# Added causation edge: government_of_pakistan -> motorway_network_development_1997
# Added event: womens_protection_bill_2006
# Added location edge: womens_protection_bill_2006 -> Pakistan
# Added group: parliament_of_pakistan
# Added causation edge: parliament_of_pakistan -> womens_protection_bill_2006
# Added event: malala_yousafzais_nobel_peace_prize_2014
# Added location edge: malala_yousafzais_nobel_peace_prize_2014 -> Pakistan
# Added group: malala_yousafzai,_kailash_satyarthi
# Added causation edge: malala_yousafzai,_kailash_satyarthi -> malala_yousafzais_nobel_peace_prize_2014
# Added event: chinaunknownpakistan_friendship_highway_completion_1986
# Added location edge: chinaunknownpakistan_friendship_highway_completion_1986 -> Pakistan
# Added group: governments_of_china_and_pakistan
# Added causation edge: governments_of_china_and_pakistan -> chinaunknownpakistan_friendship_highway_completion_1986
# Added event: benazir_income_support_programme_launch_2008
# Added location edge: benazir_income_support_programme_launch_2008 -> Pakistan
# Added causation edge: government_of_pakistan -> benazir_income_support_programme_launch_2008
# Added event: 18th_amendment_to_the_constitution_2010
# Added location edge: 18th_amendment_to_the_constitution_2010 -> Pakistan
# Added causation edge: parliament_of_pakistan -> 18th_amendment_to_the_constitution_2010
# Added event: pakistans_first_satellite_launch_1990
# Added location edge: pakistans_first_satellite_launch_1990 -> Pakistan
# Added group: suparco
# Added causation edge: suparco -> pakistans_first_satellite_launch_1990
# Added event: protection_of_women_act_2006
# Added location edge: protection_of_women_act_2006 -> Pakistan
# Added causation edge: parliament_of_pakistan -> protection_of_women_act_2006
# Added event: national_database_and_registration_authority_nadra_establishment_1998
# Added location edge: national_database_and_registration_authority_nadra_establishment_1998 -> Pakistan
# Added causation edge: government_of_pakistan -> national_database_and_registration_authority_nadra_establishment_1998
# Added event: karachi_nuclear_power_plant_operational_1972
# Added location edge: karachi_nuclear_power_plant_operational_1972 -> Pakistan
# Added group: pakistan_atomic_energy_commission
# Added causation edge: pakistan_atomic_energy_commission -> karachi_nuclear_power_plant_operational_1972
# Added event: hec_digital_library_initiative_2004
# Added location edge: hec_digital_library_initiative_2004 -> Pakistan
# Added group: higher_education_commission_of_pakistan
# Added causation edge: higher_education_commission_of_pakistan -> hec_digital_library_initiative_2004
# Added event: gwadar_port_development_2002
# Added location edge: gwadar_port_development_2002 -> Pakistan
# Added causation edge: government_of_pakistan,_china -> gwadar_port_development_2002
# Added event: national_action_plan_against_terrorism_2014
# Added location edge: national_action_plan_against_terrorism_2014 -> Pakistan
# Added causation edge: government_of_pakistan -> national_action_plan_against_terrorism_2014
# Added event: independence_from_british_rule_1948
# Added country: Sri_Lanka
# Added location edge: independence_from_british_rule_1948 -> Sri_Lanka
# Added group: don_stephen_senanayake
# Added causation edge: don_stephen_senanayake -> independence_from_british_rule_1948
# Added event: sinhala_only_act_1956
# Added location edge: sinhala_only_act_1956 -> Sri_Lanka
# Added group: solomon_bandaranaike
# Added causation edge: solomon_bandaranaike -> sinhala_only_act_1956
# Added event: 1983_black_july_riots_1983
# Added location edge: 1983_black_july_riots_1983 -> Sri_Lanka
# Added group: various_groups_and_individuals
# Added causation edge: various_groups_and_individuals -> 1983_black_july_riots_1983
# Added event: tsunami_disaster_2004
# Added location edge: tsunami_disaster_2004 -> Sri_Lanka
# Added group: unknown
# Added causation edge: unknown -> tsunami_disaster_2004
# Added event: end_of_the_civil_war_2009
# Added location edge: end_of_the_civil_war_2009 -> Sri_Lanka
# Added group: mahinda_rajapaksa,_sri_lankan_armed_forces
# Added causation edge: mahinda_rajapaksa,_sri_lankan_armed_forces -> end_of_the_civil_war_2009
# Added event: introduction_of_free_education_act_1945
# Added location edge: introduction_of_free_education_act_1945 -> Sri_Lanka
# Added group: c.w.w._kannangara
# Added causation edge: c.w.w._kannangara -> introduction_of_free_education_act_1945
# Added event: republican_constitution_of_1972_1972
# Added location edge: republican_constitution_of_1972_1972 -> Sri_Lanka
# Added group: sirimavo_bandaranaike
# Added causation edge: sirimavo_bandaranaike -> republican_constitution_of_1972_1972
# Added event: establishment_of_the_mahaweli_development_project_1977
# Added location edge: establishment_of_the_mahaweli_development_project_1977 -> Sri_Lanka
# Added group: government_of_sri_lanka
# Added causation edge: government_of_sri_lanka -> establishment_of_the_mahaweli_development_project_1977
# Added event: 1987_indounknownsri_lanka_accord_1987
# Added location edge: 1987_indounknownsri_lanka_accord_1987 -> Sri_Lanka
# Added group: j.r._jayewardene,_rajiv_gandhi
# Added causation edge: j.r._jayewardene,_rajiv_gandhi -> 1987_indounknownsri_lanka_accord_1987
# Added event: 2002_ceasefire_agreement_with_ltte_2002
# Added location edge: 2002_ceasefire_agreement_with_ltte_2002 -> Sri_Lanka
# Added group: ranil_wickremesinghe,_ltte
# Added causation edge: ranil_wickremesinghe,_ltte -> 2002_ceasefire_agreement_with_ltte_2002
# Added event: victory_over_terrorism_day_2010
# Added location edge: victory_over_terrorism_day_2010 -> Sri_Lanka
# Added causation edge: government_of_sri_lanka -> victory_over_terrorism_day_2010
# Added event: establishment_of_the_central_bank_of_sri_lanka_1950
# Added location edge: establishment_of_the_central_bank_of_sri_lanka_1950 -> Sri_Lanka
# Added causation edge: government_of_sri_lanka -> establishment_of_the_central_bank_of_sri_lanka_1950
# Added event: first_executive_president_elected_1978
# Added location edge: first_executive_president_elected_1978 -> Sri_Lanka
# Added group: j.r._jayewardene
# Added causation edge: j.r._jayewardene -> first_executive_president_elected_1978
# Added event: free_health_policy_implementation_1951
# Added location edge: free_health_policy_implementation_1951 -> Sri_Lanka
# Added causation edge: government_of_sri_lanka -> free_health_policy_implementation_1951
# Added event: 2019_easter_bombings_2019
# Added location edge: 2019_easter_bombings_2019 -> Sri_Lanka
# Added group: national_thowheeth_jamaath
# Added causation edge: national_thowheeth_jamaath -> 2019_easter_bombings_2019
# Added event: establishment_of_the_university_of_ceylon_1942
# Added location edge: establishment_of_the_university_of_ceylon_1942 -> Sri_Lanka
# Added causation edge: government_of_sri_lanka -> establishment_of_the_university_of_ceylon_1942
# Added event: land_reform_law_enacted_1972
# Added location edge: land_reform_law_enacted_1972 -> Sri_Lanka
# Added causation edge: government_of_sri_lanka -> land_reform_law_enacted_1972
# Added event: womens_franchise_act_passed_1931
# Added location edge: womens_franchise_act_passed_1931 -> Sri_Lanka
